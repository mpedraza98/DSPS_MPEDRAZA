# %% [markdown]
# <a href="https://colab.research.google.com/github/mpedraza98/DSPS_MPedraza/blob/main/Labs/lab3_PI_fbb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pylab as pl
#!pip install astropy
import astropy
from astropy import units as u


# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# What you know: The ratio of the area of the circle to the area of the square is π / 4.

# %%
def square(l, ax):
  ax.plot([-l, l], [-l, -l], 'k-')
  ax.plot([-l, l], [l, l], 'k-')
  ax.plot([-l, -l], [-l, l], 'k-')
  ax.plot([l, l], [-l, l], 'k-')

# %%
def circle(l, ax):
  theta = np.linspace(0, 360, 100)
  theta *= u.degree
  x = l * np.cos(theta.to(u.rad))
  y = l * np.sin(theta.to(u.rad))
  ax.plot(x, y, 'k-')

# %%
fig, ax = pl.subplots(figsize=(5, 5))
square(1, ax=ax)
circle(1, ax=ax)

# %%
def isin(x, y, l):
  d = np.sqrt(x**2+y**2)
  return d < l

# %%
np.random.seed(123)

# %%
# Lets generate a set of points using an uniform disbtribution for both x and y

x = np.random.uniform(-1,1,10000)
y = np.random.uniform(-1,1,10000)

pi = isin(x,y,1).sum()/10000.

# %%
print(4*pi)
# Out:
# 3.1536

# %%
ax = pl.figure(figsize = (5, 5)).add_subplot()
square(1, ax = ax)
circle(1, ax = ax)
pl.plot(np.random.uniform(-1,1,1000), np.random.uniform(-1,1,1000), '.')
